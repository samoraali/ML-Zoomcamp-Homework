# %%
# %pip install opendatasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 62.8 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 62.7 MB/s  0:00:006m0:00:01
# ...
#   WARNING: The script tqdm is installed in '/usr/local/python/3.12.1/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script slugify is installed in '/usr/local/python/3.12.1/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━ 10/15 [mypy]]  WARNING: The scripts dmypy, mypy, mypyc, stubgen and stubtest are installed in '/usr/local/python/3.12.1/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...

# %%
import opendatasets as od

# %%
# %pip install kaggle
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import kaggle
# Out:
# Could not find kaggle.json. Make sure it's located in /home/codespace/.config/kaggle. Or use the environment method. See setup instructions at https://github.com/Kaggle/kaggle-api/
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import kaggle
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/kaggle/__init__.py:10
#       8 enable_oauth = os.environ.get("KAGGLE_ENABLE_OAUTH") in ("1", "true", "yes")
#       9 api = KaggleApi(enable_oauth=enable_oauth)
# ---> 10 api.authenticate()
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/kaggle/api/kaggle_api_extended.py:685, in KaggleApi.authenticate(self)
#     678 else:
#     679     print(
#     680         "Could not find {}. Make sure it's located in"
#     681         " {}. Or use the environment method. See setup"
#     682         " instructions at"
# ...
